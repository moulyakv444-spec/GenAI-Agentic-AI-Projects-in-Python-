# %% [markdown]
# # variable declaration in python
#
# variable = value

# %%
nit=1030
nit
# Out:
# 1030

# %%
1030=nit
# Out:
#   Cell In[5], line 1
#     1030=nit
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
nit1=10
nit1
# Out:
# 10

# %%
nit1=10
NIT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 nit1=10
# ----> 2 NIT
#
# NameError: name 'NIT' is not defined

# %%
@nit=10
@nit
# Out:
#   Cell In[9], line 1
#     @nit=10
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
nit2@=25
nit2@
# Out:
#   Cell In[10], line 2
#     nit2@
#          ^
# SyntaxError: invalid syntax

# %%
nit2_=25
nit2_
# Out:
# 25

# %%
_
# Out:
# '{"dataframes": [], "user": "venka"}'

# %%
1nit=10
1nit
# Out:
#   Cell In[13], line 1
#     1nit=10
#     ^
# SyntaxError: invalid decimal literal

# %%
nit3=24
nit3
# Out:
# 24

# %%
_
# Out:
# '{"dataframes": [], "user": "venka"}'

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
true=25
true
# Out:
# 25

# %%
For = 35
For
# Out:
# 35

# %%
false = 22

# %%
else = 22
# Out:
#   Cell In[28], line 1
#     else = 22
#     ^
# SyntaxError: invalid syntax

# %%
if = 32
# Out:
#   Cell In[29], line 1
#     if = 32
#        ^
# SyntaxError: invalid syntax

# %%
For = 35
For
# Out:
# 35

# %%
for = 45
for
# Out:
#   Cell In[31], line 1
#     for = 45
#         ^
# SyntaxError: invalid syntax

# %%
# for is keyword and they are defined as a variable

# %%
true=7
true
# Out:
# 7

# %%
True=3
True
# Out:
#   Cell In[33], line 1
#     True=3
#     ^
# SyntaxError: cannot assign to True
